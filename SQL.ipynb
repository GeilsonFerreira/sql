# %% [markdown]
# <a href="https://colab.research.google.com/github/GeilsonFerreira/sql/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso de SLQ / Postgress

# %% [markdown]
# ## Criar Banco de Dados
